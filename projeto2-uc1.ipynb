# %%
def validaContinuar(continuar):
  if continuar == "s":
    return True
  else:
    return False

# %%
def validaMaiusculasSenha(maiusculas):
  if  ==  True:
    return False
  else:
    return False

# %%
mensagemBoasVindas= ("Olá, tudo bem? Seja bem vindo ao programa onde nele geraremos um código para uma senha segura especialmente pra você! \U0001F609")
print(mensagemBoasVindas)

continuar = input("Gostariamos de saber se você quer continuar o processo? (Digite s ou n)")
print(continuar)

if validaContinuar(continuar):
    print("\nVamos estar dando continuidade \U0001F60A.")
else:
    print("\nEncerramos aqui o processo \U0001F61E.")
    sys.exit()
inicio = ("\nAgora, precisamos de algumas de suas preferências para poder gerar sua senha segura  ")
meio = ("\nAbaixo, estará disponivel algumas informações para você preencher, ")
fim = ("com elas, a senha será feita de acordo com sua escolha, até mesmo na quantidade de caracteres!")
print(inicio)
print(meio)
print(fim)

numerosSenha = int(input('\nDigite o(s) número(s): '))
simbolosSenha = input('\nDigite o(s) simbolo(s): ')
maiusculasSenha = input('\nDigite a(s) letra(s) maiuscula(s): ')
if validaMaiusculasSenha(maiusculasSenha) == False:
    print("\nCaracter no input de numeros da senha inválido!!.")
    sys.exit()
minusculasSenha = input('\nDigite a(s) letra(s) minuscula(s): ')

senha = str(c) + d  + f + g
senha_segura = list(senha)
random.shuffle(senha_segura)
senha_junta = ''.join(senha_segura)

print("\nSua senha segura é:", senha_junta)

# %%
mensagemBoasVindas= ("Olá, tudo bem? Seja bem vindo ao programa onde nele geraremos um código para uma senha segura especialmente pra você! \U0001F609")
print(mensagemBoasVindas)

continuar = input("Gostariamos de saber se você quer continuar o processo? (Digite s ou n)")
print(continuar)

if validaContinuar(continuar):
    print("\nVamos estar dando continuidade \U0001F60A.")
else:
    print("\nEncerramos aqui o processo \U0001F61E.")
    sys.exit()
inicio = ("\nAgora, precisamos de algumas de suas preferências para poder gerar sua senha segura  ")
meio = ("\nAbaixo, estará disponivel algumas informações para você preencher, ")
fim = ("com elas, a senha será feita de acordo com sua escolha, até mesmo na quantidade de caracteres!")
print(inicio)
print(meio)
print(fim)

numerosSenha = int(input('\nDigite o(s) número(s): '))
simbolosSenha = input('\nDigite o(s) simbolo(s): ')
maiusculasSenha = input('\nDigite a(s) letra(s) maiuscula(s): ')
if validaMaiusculasSenha(maiusculasSenha) == False:
    print("\nCaracter no input de numeros da senha inválido!!.")
    sys.exit()
minusculasSenha = input('\nDigite a(s) letra(s) minuscula(s): ')

senha = str(c) + d  + f + g
senha_segura = list(senha)
random.shuffle(senha_segura)
senha_junta = ''.join(senha_segura)

print("\nSua senha segura é:", senha_junta)
# Out:
# Olá, tudo bem? Seja bem vindo ao programa onde nele geraremos um código para uma senha segura especialmente pra você! 😉
# Gostariamos de saber se você quer continuar o processo? (Digite s ou n)s
# s
#
# Vamos estar dando continuidade 😊.
#
# Agora, precisamos de algumas de suas preferências para poder gerar sua senha segura
#
# Abaixo, estará disponivel algumas informações para você preencher,
# com elas, a senha será feita de acordo com sua escolha, até mesmo na quantidade de caracteres!
#
# Digite o(s) número(s): 123
#
# Digite o(s) simbolo(s): *-
#
# Digite a(s) letra(s) maiuscula(s): asdas
#
# Caracter no input de numeros da senha inválido!!.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-601cb85f4f96> in <cell line: 22>()
#      22 if validaMaiusculasSenha(maiusculasSenha) == False:
#      23     print("\nCaracter no input de numeros da senha inválido!!.")
# ---> 24     sys.exit()
#      25 minusculasSenha = input('\nDigite a(s) letra(s) minuscula(s): ')
#      26
#
# NameError: name 'sys' is not defined

# %%
import random

a= ("Boa noite!")
b= ("seja bem vindo!")
c= ("tenho o objetivo de criar uma senha segura")
print( a)
print( b)
print( c)

c= int(input('digite o primeiro numero: '))
d= input('digite um simbolo: ')
e= int(input('digite o segundo numero: '))
f= input('digite a primera letra maiuscula: ')
g= input('digite a primera letra minuscula: ')
h= input('digite a segunda letra minuscula: ')

senha = str(c) + d + str(e) + f + g + h

senha_segura = list(senha)

random.shuffle(senha_segura)

senha_junta = ''.join(senha_segura)


print("Sua senha segura é:", senha_junta)
# Out:
# Boa noite!
# seja bem vindo!
# tenho o objetivo de criar uma senha segura
# digite o primeiro numero: 5
# digite um simbolo: =
# digite o segundo numero: 4
# digite a primera letra maiuscula: L
# digite a primera letra minuscula: n
# digite a segunda letra minuscula: d
# Sua senha segura é: =d5nL4

# %%
a= ("Boa noite!")
b= ("seja bem vindo!")
c= ("tenho o objetivo de criar uma senha segura")
print( a)
print( b)
print( c)

c= int(input('digite o primeiro numero: '))
d= input('digite um simbolo: ')
e= int(input('digite o segundo numero: '))



f= input('digite a primera letra maiuscula: ')
g= input('digite a primera letra minuscula: ')
h= input('digite a segunda letra minuscula: ')
i= input('digite a segunda letra maiuscula: ')
j= input('digite a')
k=
l=
m=
n=
o=
p=
q=
r=

senha = str(c) + d + str(e) + f + g + h

print("Sua senha segura é:", senha)

# %%
a= ("Boa noite!")
b= ("seja bem vindo!")
c= ("tenho o objetivo de criar uma senha segura")
print( a)
print( b)
print( c)

import random
nome = input('Digite seu nome: ')
cpf = str(random.randint('Digite seu CPF: '))
data_nascimento = int(input('digite sua data de nascimento (DDMMAAAA): '))
print(nome, cpf, data_nascimento)
senha = (nome+cpf+data_nascimento)

print("Sua senha segura é:", senha)
# Out:
# Boa noite!
# seja bem vindo!
# tenho o objetivo de criar uma senha segura
# Digite seu nome: mnvpç
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-5e1a26d083bc> in <cell line: 10>()
#       8 import random
#       9 nome = input('Digite seu nome: ')
# ---> 10 cpf = str(random('Digite seu CPF: '))
#      11 data_nascimento = int(input('digite sua data de nascimento (DDMMAAAA): '))
#      12 print(nome, cpf, data_nascimento)
#
# TypeError: 'module' object is not callable

# %%
a= ("Boa noite!")
b= ("seja bem vindo!")
c= ("tenho o objetivo de criar uma senha segura")
print( a)
print( b)
print( c)

nome = input('Digite seu nome: ')
cpf = input('Digite seu CPF (apenas números): ')
cpf = cpf.zfill(11)
data_nascimento = int(input('digite sua data de nascimento (DDMMAAAA): '))



print("Sua senha segura é:", senha)
# Out:
#   File "<ipython-input-16-d4d4674b3ad9>", line 16
#     print("Sua senha segura é:", senha)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 14

# %%
nome = input('Digite seu nome: ')
cpf = input('Digite seu CPF (apenas números): ')
cpf = cpf.zfill(11)
data_nascimento = input('Digite sua data de nascimento (DDMMAAAA): ')

# Aqui você pode adicionar algum tipo de manipulação para gerar a senha de forma indireta
senha = nome[:3] + str(int(cpf) % 1000) + data_nascimento[-2:]

print("Sua senha é:", senha)
# Out:
# Digite seu nome: manu[
# Digite seu CPF (apenas números): 12345678998
# Digite sua data de nascimento (DDMMAAAA): 20322222
# Sua senha é: man99822

# %%
import random

a = "Boa noite!"
b = "Seja bem vindo!"
c = "Tenho o objetivo de criar uma senha segura."
print(a)
print(b)
print(c)

nome = input('Digite seu nome: ')
cpf = input('Digite seu CPF (apenas números): ')
cpf = cpf.zfill(11)
letra_maiucusla = input('Digite uma letra maiuscula: ')
data_nascimento = int(input('Digite sua data de nascimento (DDMMAAAA): '))
caracteres_especiais = input('digite dois caracteres especiais:' )
if len(cpf) == 11:

    senha = nome[:3] + cpf[:7] + letra_maiucusla[:1] + str(data_nascimento)[:2] + caracteres_especiais[:2]
    print("Sua senha é:", senha)
else:
    print("CPF inválido. O CPF deve conter 11 dígitos.")

if len(str(data_nascimento)) == 8:
    senha = nome[:3] + cpf[:7] + letra_maiucusla[:1] + str(data_nascimento)[:2] + caracteres_especiais[:2]
    print("Sua senha é:", senha)
else:
    print("Data de nascimento invalida. Nele deve conter 4 dígitos.")
# Out:
# Boa noite!
# Seja bem vindo!
# Tenho o objetivo de criar uma senha segura.
# Digite seu nome: manu
# Digite seu CPF (apenas números): 12345678952
# Digite uma letra maiuscula: M
# Digite sua data de nascimento (DDMMAAAA): 12054789302
# digite dois caracteres especiais:#$
# Sua senha é: man1234567M12#$
# Data de nascimento invalida. Nele deve conter 4 dígitos.

# %%
import random

a = "Boa noite!"
b = "Seja bem vindo!"
c = "Tenho o objetivo de criar uma senha segura."
print(a)
print(b)
print(c)

nome = input('Digite seu nome: ')
cpf = input('Digite seu CPF (apenas números): ')
cpf = cpf.zfill(11)
data_nascimento = int(input('Digite sua data de nascimento (DDMMAAAA): '))
caracteres_especiais= ('digite dois caracteres especiais' )
if len(cpf) == 11:

    senha = nome[:3] + cpf[-2:] + str(data_nascimento)[-2:]
    print("Sua senha é:", senha)
else:
    print("CPF inválido. O CPF deve conter 11 dígitos.")

# %%
import random

a = "Boa noite!"
b = "Seja bem vindo!"
c = "Tenho o objetivo de criar uma senha segura."
print(a)
print(b)
print(c)

nome = input('Digite seu nome: ')
cpf = input('Digite seu CPF (apenas números): ')
cpf = cpf.zfill(11)
letra_maiucusla = input('Digite uma letra maiuscula: ')
data_nascimento = int(input('Digite sua data de nascimento (DDMMAAAA): '))
caracteres_especiais = input('digite dois caracteres especiais:' )
if len(cpf) == 11:

    senha = nome[:3] + cpf[:7] + letra_maiucusla[:1] + str(data_nascimento)[:2] + caracteres_especiais[:2]
    print("Sua senha é:", senha)
else:
    print("CPF inválido. O CPF deve conter 11 dígitos.")

if len(str(data_nascimento)) == 8:
    senha = nome[:3] + cpf[:7] + letra_maiucusla[:1] + str(data_nascimento)[:2] + caracteres_especiais[:2]
    print("Sua senha é:", senha)
else:
    print("Data de nascimento invalida. Nele deve conter 4 dígitos.")
